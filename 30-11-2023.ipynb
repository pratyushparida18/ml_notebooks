# %%
import numpy as np
from tensorflow.keras.models import Sequential
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Dense, Flatten

# %%
X_train = np.loadtxt('/home/pratyush/Downloads//Image Classification CNN Keras Dataset/input.csv', delimiter = ',')
Y_train = np.loadtxt('/home/pratyush/Downloads//Image Classification CNN Keras Dataset/labels.csv', delimiter = ',')

X_test = np.loadtxt('/home/pratyush/Downloads//Image Classification CNN Keras Dataset/input_test.csv', delimiter = ',')
Y_test = np.loadtxt('/home/pratyush/Downloads//Image Classification CNN Keras Dataset/labels_test.csv', delimiter = ',')

# %%
X_train = X_train.reshape(len(X_train),100,100,3)
Y_train = Y_train.reshape(len(Y_train),1)

X_test = X_test.reshape(len(X_test),100,100,3)
Y_test = Y_test.reshape(len(Y_test),1)

X_train = X_train/255.0
Y_test = Y_test/255.0

# %%
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (2000, 100, 100, 3)
# (2000, 1)
# (400, 100, 100, 3)
# (400, 1)

# %%
X_train
# Out:
# array([[[[0.14509804, 0.15294118, 0.09803922],
#          [0.10196078, 0.09411765, 0.03529412],
#          [0.13333333, 0.09803922, 0.03921569],
#          ...,
#          [0.22352941, 0.17254902, 0.1372549 ],
#          [0.23921569, 0.18431373, 0.14901961],
#          [0.25490196, 0.2       , 0.16470588]],
#
#         [[0.17647059, 0.16862745, 0.10980392],
#          [0.10980392, 0.09803922, 0.03137255],
#          [0.20392157, 0.15686275, 0.09411765],
#          ...,
#          [0.21176471, 0.16078431, 0.1254902 ],
#          [0.22352941, 0.16862745, 0.13333333],
#          [0.23921569, 0.18431373, 0.14901961]],
#
#         [[0.20392157, 0.17647059, 0.10196078],
#          [0.1254902 , 0.09411765, 0.01960784],
#          [0.27058824, 0.21176471, 0.1372549 ],
#          ...,
#          [0.21176471, 0.15686275, 0.11372549],
#          [0.21960784, 0.16470588, 0.12156863],
#          [0.23137255, 0.17647059, 0.13333333]],
#
#         ...,
#
# ...

# %%
plt.imshow(X_train[1,:])
plt.show()

# %%
model = Sequential([
    Conv2D(32,(3,3),activation = 'relu', input_shape=(100,100,3)),
    MaxPooling2D((2,2)),
    
    Conv2D(32,(3,3),activation = 'relu', ),
    MaxPooling2D((2,2)),
    
    Flatten(),
    Dense(64,activation = 'relu'),
    Dense(1,activation = 'sigmoid')
])

# %%
model.compile(loss = 'binary_crossentropy', optimizer='adam', metrics = ['accuracy'])

# %%
model.fit(X_train,Y_train,epochs = 10, batch_size = 64)
# Out:
# Epoch 1/10
# 32/32 [==============================] - 4s 121ms/step - loss: 0.7076 - accuracy: 0.5180
# Epoch 2/10
# 32/32 [==============================] - 4s 116ms/step - loss: 0.6890 - accuracy: 0.5395
# Epoch 3/10
# 32/32 [==============================] - 4s 114ms/step - loss: 0.6645 - accuracy: 0.6020
# Epoch 4/10
# 32/32 [==============================] - 4s 116ms/step - loss: 0.6123 - accuracy: 0.6625
# Epoch 5/10
# 32/32 [==============================] - 4s 115ms/step - loss: 0.5619 - accuracy: 0.7135
# Epoch 6/10
# 32/32 [==============================] - 4s 119ms/step - loss: 0.5122 - accuracy: 0.7535
# Epoch 7/10
# 32/32 [==============================] - 4s 115ms/step - loss: 0.4619 - accuracy: 0.7895
# Epoch 8/10
# 32/32 [==============================] - 4s 115ms/step - loss: 0.4265 - accuracy: 0.8110
# Epoch 9/10
# 32/32 [==============================] - 4s 113ms/step - loss: 0.3765 - accuracy: 0.8300
# Epoch 10/10
# ...

# %%
 model.evaluate(X_test,Y_test)
# Out:
# 13/13 [==============================] - 0s 24ms/step - loss: 112.6323 - accuracy: 0.3975
# [112.6323471069336, 0.39750000834465027]

# %%
# import random

# y_pred = model.predict(X_test[10, : ].reshape(1,100,100,3))
# print(y_pred)

# %%
pip cache purge
pip install tensorflow-gpu
# Out:
#   Cell In[5], line 1
#     pip cache purge
#         ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
# Out:
# 2023-11-30 16:11:10.096466: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-11-30 16:11:10.123783: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-30 16:11:10.327261: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-30 16:11:10.327378: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...

# %%
dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
data_dir = tf.keras.utils.get_file('flower_photos', origin=dataset_url,  cache_dir='/home/pratyush/Downloads/', untar=True)

# %%
import pathlib
data_dir = pathlib.Path(data_dir)
data_dir
# Out:
# PosixPath('/home/pratyush/Downloads/datasets/flower_photos')

# %%
list(data_dir.glob('*/*.jpg'))[:5]
# Out:
# [PosixPath('/home/pratyush/Downloads/datasets/flower_photos/dandelion/4573204385_9b71e96b35_m.jpg'),
#  PosixPath('/home/pratyush/Downloads/datasets/flower_photos/dandelion/9533964635_f38e6fa3c3.jpg'),
#  PosixPath('/home/pratyush/Downloads/datasets/flower_photos/dandelion/2497301920_91490c42c0.jpg'),
#  PosixPath('/home/pratyush/Downloads/datasets/flower_photos/dandelion/14202166370_e989588332.jpg'),
#  PosixPath('/home/pratyush/Downloads/datasets/flower_photos/dandelion/11405573_24a8a838cc_n.jpg')]

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 3670

# %%
roses = list(data_dir.glob('roses/*'))
roses[:5]
# Out:
# [PosixPath('/home/pratyush/Downloads/datasets/flower_photos/roses/3560426426_1c66cb8330.jpg'),
#  PosixPath('/home/pratyush/Downloads/datasets/flower_photos/roses/12562723334_a2e0a9e3c8_n.jpg'),
#  PosixPath('/home/pratyush/Downloads/datasets/flower_photos/roses/8949720453_66e8304c30.jpg'),
#  PosixPath('/home/pratyush/Downloads/datasets/flower_photos/roses/5578766623_542c91dfaa_n.jpg'),
#  PosixPath('/home/pratyush/Downloads/datasets/flower_photos/roses/8674140377_ae7b0be523.jpg')]

# %%
PIL.Image.open(str(roses[1]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x240>

# %%
flowers_images_dict = {
    'roses': list(data_dir.glob('roses/*')),
    'daisy': list(data_dir.glob('daisy/*')),
    'dandelion': list(data_dir.glob('dandelion/*')),
    'sunflowers': list(data_dir.glob('sunflowers/*')),
    'tulips': list(data_dir.glob('tulips/*')),
}

# %%
flowers_labels_dict = {
    'roses': 0,
    'daisy': 1,
    'dandelion': 2,
    'sunflowers': 3,
    'tulips': 4,
}

# %%
flowers_images_dict['roses'][:5]
# Out:
# [PosixPath('/home/pratyush/Downloads/datasets/flower_photos/roses/3560426426_1c66cb8330.jpg'),
#  PosixPath('/home/pratyush/Downloads/datasets/flower_photos/roses/12562723334_a2e0a9e3c8_n.jpg'),
#  PosixPath('/home/pratyush/Downloads/datasets/flower_photos/roses/8949720453_66e8304c30.jpg'),
#  PosixPath('/home/pratyush/Downloads/datasets/flower_photos/roses/5578766623_542c91dfaa_n.jpg'),
#  PosixPath('/home/pratyush/Downloads/datasets/flower_photos/roses/8674140377_ae7b0be523.jpg')]

# %%
img = cv2.imread(str(flowers_images_dict['roses'][0]))

# %%
img.shape
# Out:
# (333, 500, 3)

# %%
cv2.resize(img,(180,180)).shape
# Out:
# (180, 180, 3)

# %%
X, y = [], []

for flower_name, images in flowers_images_dict.items():
    for image in images:
        img = cv2.imread(str(image))
        resized_img = cv2.resize(img,(180,180))
        X.append(resized_img)
        y.append(flowers_labels_dict[flower_name])

# %%
X = np.array(X)
y = np.array(y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
X_train_scaled = X_train / 255
X_test_scaled = X_test / 255

# %%
num_classes = 5

model = Sequential([
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
              
model.fit(X_train_scaled, y_train, epochs=30)
# Out:
# Epoch 1/30
# 86/86 [==============================] - 15s 166ms/step - loss: 1.3676 - accuracy: 0.4237
# Epoch 2/30
# 86/86 [==============================] - 14s 166ms/step - loss: 1.0350 - accuracy: 0.5948
# Epoch 3/30
# 86/86 [==============================] - 14s 163ms/step - loss: 0.8383 - accuracy: 0.6799
# Epoch 4/30
# 86/86 [==============================] - 14s 165ms/step - loss: 0.6409 - accuracy: 0.7613
# Epoch 5/30
# 86/86 [==============================] - 14s 165ms/step - loss: 0.4400 - accuracy: 0.8434
# Epoch 6/30
# 86/86 [==============================] - 14s 164ms/step - loss: 0.2586 - accuracy: 0.9139
# Epoch 7/30
# 86/86 [==============================] - 14s 165ms/step - loss: 0.1483 - accuracy: 0.9535
# Epoch 8/30
# 86/86 [==============================] - 14s 165ms/step - loss: 0.0886 - accuracy: 0.9749
# Epoch 9/30
# 86/86 [==============================] - 14s 164ms/step - loss: 0.0610 - accuracy: 0.9862
# Epoch 10/30
# ...

# %%
model.evaluate(X_test_scaled,y_test)
# Out:
# 29/29 [==============================] - 2s 66ms/step - loss: 2.6476 - accuracy: 0.6198
# [2.6476247310638428, 0.6198257207870483]

# %%
data_augmentation = keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal", 
                                                 input_shape=(180, 
                                                              180,
                                                              3)),
    layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.1),
  ]
)

# %%
plt.axis('off')
plt.imshow(X[0])

# %%
X[0].shape
# Out:
# (180, 180, 3)

# %%
plt.axis('off')
plt.imshow(data_augmentation(X)[0].numpy().astype("uint8"))

# %%
num_classes = 5

model = Sequential([
  data_augmentation,
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
              
model.fit(X_train_scaled, y_train, epochs=30)
